# %% [markdown]
# <a href="https://colab.research.google.com/github/coderhouse2025-droid/SUPERTIENDA/blob/main/Supertienda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Supertienda.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **ABSTRACT**
#
# Análisis de Ventas de Supertienda en Latinoamérica.
# El Dataset seleccionado para este análisis es "Supertienda", una base de datos disponible en la plataforma Kaggle. Este Dataset contiene un registro detallado de las ventas de productos de oficina en Latinoamérica durante el período comprendido entre 2019 y 2023. La base de datos proporciona información exhaustiva sobre las ventas segmentadas por región, país, estado y categorías de productos, entre otros atributos relevante.
# El objetivo principal de esta presentación es llevar a cabo un análisis detallado y visual de las ventas de Supertienda en Latinoamérica. Específicamente, se busca responder preguntas claves del negocio, como la identificación de los productos más demandados y la estratificación de las ventas en las distintas regiones.
# Para lograr este objetivo, se aplicaron técnicas de análisis de datos exploratorio, utilizando herramientas de Almacenamiento en la nube, visualización y manipulación de datos ampliamente reconocidas en la industria, como Google drive, squite3, Matplotlib, Seaborn y Pandas.(Nuevas bibliotecas y API)
#
# **Desarrollo de las Tareas y Metodología**
#
# El proceso de análisis comenzó con la importación del archivo de datos desde un formato Excel alojada en la nube (Google Drive) Se procedió a realizar una limpieza y procesar los datos para identificar y gestionar valores faltantes. Este paso es fundamental para asegurar la calidad y fiabilidad de los resultados.
# Posteriormente, se crearon visualizaciones que permiten responder a las preguntas estratégicas del negocio. Este análisis exploratorio inicial no solo proporciona insights valiosos sobre el desempeño actual de las ventas, sino que también sentará las bases para futuros proyectos más avanzados, como la predicción de ventas, la segmentación de clientes o la implementación de sistemas de recomendación.
#
# **Ejes de Análisis**
#
# ¿Quiénes son los principales segmentos de clientes para Supertienda?
#
# ¿Cuáles fueron los productos con mayor volumen de ventas durante el periodo?
#
# ¿Cuál es la región que genera mayores ingresos y cuáles son los tres países con mejores desempeños dentro de esta región?
#
# **Declaración de Intenciones del Proyecto**
#
# El objetivo de este proyecto es desarrollar un modelo predictivo que, a partir del análisis exhaustivo de las transacciones comerciales registradas entre 2019 y 2023, permita identificar y determinar las zonas geográficas más lucrativas. Este análisis se realizará con un enfoque detallado a nivel de región y se centrará en los productos vendidos por la empresa.
#
# **Alcance y Beneficios del Proyecto**
#
# La implementación de este modelo facilitará un análisis profundo de los aspectos clave, lo que se traducirá en beneficios significativos para clientes internos y externos de la empresa. La información generada contribuirá a:
#
# • Optimización de la cadena de suministro: Identificar patrones de compra de los clientes para ajustar y optimizar los pedidos a proveedores.
#
# • Segmentación de mercado: Determinar y definir con precisión los segmentos de clientes clave.
#
# • Evaluación de rendimiento: Medir y evaluar el desempeño de las ventas por país y región.
#
# • Mejora de la experiencia del cliente: Comprender las preferencias de productos para enriquecer la experiencia de compra.
#
# • Gestión de inventario: Apoyar el control de stock y la planificación estratégica de futuras compras. (Ubicación geográfica)
#
# • Toma de decisiones: Proveer información sólida para la toma de decisiones en todos los niveles de la empresa.
#
# • Además, este proyecto permitirá abordar otros temas relevantes para la planificación estratégica y el crecimiento sostenible de la empresa.

# %% [markdown]
# **Montar Google Drive en este entorno de Colab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Instalar gdown**
#
# (herramienta diseñada para facilitar la descarga de archivos de Google Drive a través de comandos de línea de
# comandos).

# %%
# !pip install -q gdown

# %% [markdown]
# **Descargar base de datos de Supertienda desde Google Drive**

# %%
file_id = '1d45NdxZYAJMh7an2sJNgLwTWnUUaMClQ'
output_filename = 'Supertienda.xlsx'
# !gdown --id $file_id -O $output_filename
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1d45NdxZYAJMh7an2sJNgLwTWnUUaMClQ
# To: /content/Supertienda.xlsx
# 100% 1.45M/1.45M [00:00<00:00, 119MB/s]

# %% [markdown]
# **Importar Pandas**
#
# (biblioteca de código abierto diseñada para facilitar el análisis y manipulación de datos en Python)

# %%
import pandas as pd
df = pd.read_excel("/content/Supertienda.xlsx")
display(df.head())
# Out:
#    Id. de la fila  Id. del pedido Fecha del pedido Fecha de envío  \
# 0             128  AR-2021-112368       2021-06-08     2021-06-12
# 1             129  AR-2021-112368       2021-06-08     2021-06-12
# 2             133  AR-2020-130631       2020-09-17     2020-09-22
# 3             134  AR-2020-130631       2020-09-17     2020-09-22
# 4             135  AR-2020-130631       2020-09-17     2020-09-22
#
#   Forma de envío Id. del cliente Nombre del cliente Segmento        Ciudad  \
# 0         Rápido        TJ-21265        Tito Jáquez  Empresa  Buenos Aires
# 1         Rápido        TJ-21265        Tito Jáquez  Empresa  Buenos Aires
# 2         Rápido        RZ-20275       Rafel Zarate  Cliente   Resistencia
# 3         Rápido        RZ-20275       Rafel Zarate  Cliente   Resistencia
# 4         Rápido        RZ-20275       Rafel Zarate  Cliente   Resistencia
#
#                             Estado País/Región Región Id. del producto  \
# ...

# %% [markdown]
# **Importar squite3**
#
# (sistema de gestión de bases de datos relacional ligero, autónomo y sin servidor, ideal para aplicaciones que requieren almacenamiento local de datos)

# %%
import sqlite3

# %% [markdown]
# **Conectar con el archivo**
#
# (cargar del DataFrame actual (df) en una tabla llamada 'supertienda_table' para luego consultar las tablas de esta nueva base de datos. Esto permitirá usar SQL con los datos)

# %%
conn = sqlite3.connect(':memory:') # Create an in-memory SQLite database
df.to_sql('supertienda_table', conn, if_exists='replace', index=False)

tables = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table'",
    conn
)
print("Tablas encontradas:", tables['name'].tolist())
# Out:
# Tablas encontradas: ['supertienda_table']

# %% [markdown]
# **Ejecutar la celda para listar las tablas de la base de datos Supertienda_table**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11964 entries, 0 to 11963
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id. de la fila       11964 non-null  int64
#  1   Id. del pedido       11964 non-null  object
#  2   Fecha del pedido     11964 non-null  datetime64[ns]
#  3   Fecha de envío       11964 non-null  datetime64[ns]
#  4   Forma de envío       11964 non-null  object
#  5   Id. del cliente      11964 non-null  object
#  6   Nombre del cliente   11964 non-null  object
#  7   Segmento             11964 non-null  object
#  8   Ciudad               11964 non-null  object
#  9   Estado               11964 non-null  object
#  10  País/Región          11964 non-null  object
#  11  Región               11964 non-null  object
#  12  Id. del producto     11964 non-null  object
#  13  Categoría            11964 non-null  object
#  14  Subcategoría         11964 non-null  object
# ...

# %% [markdown]
# # **Data Clearing**

# %% [markdown]
# **Verificar y eliminar filas duplicadas**

# %%
print(f"Número de filas antes de eliminar duplicados: {len(df)}")
df.drop_duplicates(inplace=True)
print(f"Número de filas después de eliminar duplicados: {len(df)}")
# Out:
# Número de filas antes de eliminar duplicados: 11964
# Número de filas después de eliminar duplicados: 11964

# %% [markdown]
# **Convertir columnas categóricas a tipo "category"**
#
# (Convertir columnas categóricas a tipo 'category'
# Esto optimiza el uso de memoria y puede mejorar el rendimiento en ciertas operaciones).

# %%
categorical_cols = [
    'Forma de envío', 'Segmento', 'Ciudad', 'Estado', 'País/Región',
    'Región', 'Categoría', 'Subcategoría'
]

for col in categorical_cols:
    if col in df.columns:
        df[col] = df[col].astype('category')

print("Tipos de datos actualizados para columnas categóricas:")
display(df[categorical_cols].info())
# Out:
# Tipos de datos actualizados para columnas categóricas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11964 entries, 0 to 11963
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Forma de envío  11964 non-null  category
#  1   Segmento        11964 non-null  category
#  2   Ciudad          11964 non-null  category
#  3   Estado          11964 non-null  category
#  4   País/Región     11964 non-null  category
#  5   Región          11964 non-null  category
#  6   Categoría       11964 non-null  category
#  7   Subcategoría    11964 non-null  category
# dtypes: category(8)
# memory usage: 149.4 KB
# None

# %% [markdown]
# **Mostrar información general del DataFrame después de la limpieza**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11964 entries, 0 to 11963
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id. de la fila       11964 non-null  int64
#  1   Id. del pedido       11964 non-null  object
#  2   Fecha del pedido     11964 non-null  datetime64[ns]
#  3   Fecha de envío       11964 non-null  datetime64[ns]
#  4   Forma de envío       11964 non-null  category
#  5   Id. del cliente      11964 non-null  object
#  6   Nombre del cliente   11964 non-null  object
#  7   Segmento             11964 non-null  category
#  8   Ciudad               11964 non-null  category
#  9   Estado               11964 non-null  category
#  10  País/Región          11964 non-null  category
#  11  Región               11964 non-null  category
#  12  Id. del producto     11964 non-null  object
#  13  Categoría            11964 non-null  category
# ...

# %% [markdown]
# # **Exploración de Datos (EDA - Exploratory Data Analysis)**

# %% [markdown]
# **Resumen estadístico de las columnas numéricas**
#
# (El método **"describe"** proporciona estadísticas descriptivas que resumen la tendencia central, la dispersión y la forma de la distribución de un conjunto de datos, excluyendo los valores** **"NaN"**).

# %% [markdown]
# **Visualización de la distribución de "Venta" y "Ganancia"**
#
# (histogramas para observar la forma general de la distribución y los box plots para identificar la mediana, los cuartiles y la presencia de valores atípicos).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 9))

# Histograma de 'Venta'
plt.subplot(1, 2, 1) # 1 fila, 2 columnas, primer gráfico
sns.histplot(df['Venta'], bins=50, kde=True)
plt.title('Distribución de Venta')
plt.xlabel('Venta')
plt.ylabel('Frecuencia')

# Histograma de 'Ganancia'
plt.subplot(1, 2, 2) # 1 fila, 2 columnas, segundo gráfico
sns.histplot(df['Ganancia'], bins=50, kde=True)
plt.title('Distribución de Ganancia')
plt.xlabel('Ganancia')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 9))

# Box plot de 'Venta'
plt.subplot(1, 2, 1) # 1 fila, 2 columnas, primer gráfico
sns.boxplot(y=df['Venta'])
plt.title('Box Plot de Venta')
plt.ylabel('Venta')

# Box plot de 'Ganancia'
plt.subplot(1, 2, 2) # 1 fila, 2 columnas, segundo gráfico
sns.boxplot(y=df['Ganancia'])
plt.title('Box Plot de Ganancia')
plt.ylabel('Ganancia')

plt.tight_layout()
plt.show()

# %%
display(df.describe())
# Out:
#        Id. de la fila               Fecha del pedido  \
# count    11964.000000                          11964
# mean      5982.500000  2021-06-02 17:11:51.334001920
# min          1.000000            2019-01-01 00:00:00
# 25%       2991.750000            2020-05-29 00:00:00
# 50%       5982.500000            2021-05-23 00:00:00
# 75%       8973.250000            2022-06-08 00:00:00
# max      11964.000000            2023-12-31 00:00:00
# std       3453.853645                            NaN
#
#                       Fecha de envío         Venta      Cantidad  \
# count                          11964  11964.000000  11964.000000
# mean   2021-06-06 16:29:07.642928640   3686.704066      3.740388
# min              2019-01-05 00:00:00     15.660000      1.000000
# 25%              2020-06-01 00:00:00    352.200000      2.000000
# 50%              2021-05-26 00:00:00   1002.600000      3.000000
# 75%              2022-06-12 00:00:00   3988.395000      5.000000
# ...

# %% [markdown]
# **Exploración de columnas categóricas**
#
# (Para ver cuántos valores únicos hay y cuáles son las categorías más frecuentes para entender la diversidad de los datos en cada categoría).

# %%
categorical_cols = df.select_dtypes(include='category').columns

for col in categorical_cols:
    print(f"\nColumna: {col}")
    print(df[col].value_counts())
    print(f"Número de valores únicos: {df[col].nunique()}")
# Out:
# Columna: Forma de envío
# Forma de envío
# Estándar     7180
# Rápido       2485
# Urgente      1697
# Mismo día     602
# Name: count, dtype: int64
# Número de valores únicos: 4
#
# Columna: Segmento
# Segmento
# Cliente            6192
# Empresa            3566
# Pequeña empresa    2206
# Name: count, dtype: int64
# Número de valores únicos: 3
#
# Columna: Ciudad
# Ciudad
# Managua             740
# Santo Domingo       516
# Ciudad de México    481
# Tegucigalpa         391
# San Salvador        256
#                    ...
# Araraquara            1
# Uberlândia            1
# Arcoverde             1
# Valle Hermoso         1
# Abreu e Lima          1
# Name: count, Length: 579, dtype: int64
# Número de valores únicos: 579
#
# Columna: Estado
# Estado
# Managua              740
# San Salvador         738
# Distrito Federal     556
# Distrito Nacional    516
# Guatemala            465
#                     ...
# Lima                   1
# La Rioja               1
# ...

# %% [markdown]
# **Hallazgos Principales del EDA**
#
# 1.  **Estado del DataFrame:** cargado y limpiado el DataFrame **"df"**. No se encontraron filas duplicadas y las columnas categóricas se han convertido al tipo **"category"** para optimizar el rendimiento y el uso de memoria.
#
# 2.  **Características de las Ventas y Ganancias:**
#     *   **"Venta y Ganancia"** muestran distribuciones altamente sesgadas a la derecha, con una gran cantidad de valores en el rango inferior y una 'cola larga' de valores muy altos.
#     *   Ambas columnas presentan **"numerosos valores atípicos (outliers)"**. En particular, **"Ganancia"** tiene valores negativos significativos (pérdidas), llegando a -18062.40, lo que sugiere la existencia de transacciones no rentables que requieren un análisis más profundo.
#     *   A pesar de las pérdidas, la ganancia promedio es positiva, pero la presencia de estas pérdidas es un punto crítico.
#
# 3.  **Patrones en Datos Categóricos:**
#     *   **Forma de Envío:** La opción "Estándar" es la más utilizada.
#     *   **Segmento de Clientes:** La mayoría de los clientes pertenecen al segmento "Cliente", seguido de "Empresa" y "Pequeña empresa".
#     *   **Geografía:** Hay una amplia distribución geográfica, con 579 ciudades y 199 estados únicos. "México" es el país con más transacciones y las regiones "Centro" y "Sur" son las más activas.
#     *   **Categorías de Producto:** "Material de oficina" es la categoría principal en volumen, seguida por "Mobiliario" y "Tecnología". Las "Carpetas" y "Sillas" son las subcategorías más frecuentes.
#
# Estos hallazgos iniciales nos dan una visión clara de la estructura y los puntos clave del conjunto de datos, señalando áreas como las transacciones no rentables y las ventas de alto valor que podrían merecer una investigación más detallada.
